# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
x=50
y="KLH-BOWRAMPET"
z=5.5
print(x," ",y," ",z)
# Out:
# 50   KLH-BOWRAMPET   5.5

# %%
x,y,z="orange","banana","cherry"
print(x," ",y," ",z)
x=y=z="orange"
print(x)
# Out:
# orange   banana   cherry
# orange

# %%
print("hello","world","This is a python class",sep=",")
print("hello",",""world")
# Out:
# hello,world,This is a python class
# hello ,world

# %%
a=int(input("Enter a number for a:"))
b=int(input("Enter a number for b:"))
c=int(input("Enter a number for c:"))
print("Sum of three numbers is: ",a+b+c)
# Out:
# Enter a number for a:1
# Enter a number for b:2
# Enter a number for c3
# Sum of three numbers is:  6

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
  print(a," is greater than", b,c)
elif b>a and b>c:
  print(b," is greater than", a,c)
else:
  print(c," is greater than", a,b)
# Out:
# 1
# 2
# 3
# 3  is greater than 1 2

# %%
x=1
y=1.2
z=1j
print(type(x)) #to verify any object in py ,we use type()
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x=int(1)
y=int(2.8)
z=int(3)
print(x,y,z)
a=float(x)
b=float(y)
c=float(z)
print(a,b,c)
d=str("Welcome")
e=str(x)
f=str(y)
print(d,e,f)
# Out:
# 1 2 3
# 1.0 2.0 3.0
# Welcome 1 2

# %%
b="Sairaj"
print(b[2:4])
print(b[:4])
print(b[2:])
print(b[:-1])
# Out:
# ir
# Sair
# iraj
# Saira

# %%
#string handling
a="Sai raj"
print(a.lower())
print(a.find('a'))
print(a.capitalize())
print(a.swapcase())
print(a.title())
print(len(a))

#concatinate
a="klh"
b="bowrampet"
c=a+b
print(c)
# Out:
# sai raj
# 1
# Sai raj
# sAI RAJ
# Sai Raj
# 7
# klhbowrampet

# %%
i=1
while i<6:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while i<6:
  print(i)
  if i==3:
    break
  i+=1
# Out:
# 1
# 2
# 3

# %%
i=1
while i<6:
  i+=1
  if i==3:
    continue
  print(i)
# Out:
# 2
# 4
# 5
# 6
