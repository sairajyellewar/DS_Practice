# %%
import pandas as pd
df=pd.DataFrame({'study_hours':[2,4,6,9,10],'marks':[20,40,60,80,100]})
correlation=df['study_hours'].corr(df['marks'])
print (correlation)
# Out:
# 0.9921567416492214

# %%
import pandas as pd
df=pd.DataFrame({'study_hours':[2,4,6,9,10],'marks':[20,40,60,80,100]})
covariance=df['study_hours'].cov(df['marks'])
print (covariance)
# Out:
# 105.0

# %%
import numpy as np
from scipy import stats
b=np.array([120,122,118,130,125,128,115,121,123,119])
a=np.array([115,120,112,128,122,125,110,117,119,114])
alpha =0.05
t_stat,p_value=stats.ttest_rel(a,b)
m=np.mean(a-b)
s=np.std(a-b,ddof=1)
n=len(b)
t_manual=m/(s/np.sqrt(n))
decision="reject" if p_value<=alpha else "fail to reject"
conclusion="significant difference" if decision == "reject" else "no significant difference"
print("T",t_stat)
print("P",p_value)
print("T manual",t_manual)
print(f"Decision:{decision} H0 at a={alpha}")
print("Conclusion",conclusion)
# Out:
# T -9.0
# P 8.538051223166285e-06
# T manual -9.0
# Decision:reject H0 at a=0.05
# Conclusion significant difference

# %%
import scipy.stats as stats
t_statistic=5.13
deg_of_freedom=63
p_value=2*(1-stats.t.cdf(t_statistic,deg_of_freedom))
print(p_value)
# Out:
# 2.9918663893013786e-06

# %%
import numpy as np
from statsmodels.stats.weightstats import ztest
data=np.random.normal(loc=11,scale=0.5,size=100)
population_mean=12
population_std_dev=0.5
z_statistic,p_value=ztest(data,value=population_mean)
print(f"Z-statistic:{z_statistic}")
print(f"p_value:{p_value}")
alpha=0.05
if p_value<alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# Z-statistic:-19.341117762517257
# p_value:2.4216868221233874e-83
# Reject the null hypothesis

# %%
import numpy as np
sample_mean=510
population_mean=500
population_std=30
n=36
z=(sample)

# %%
# chi square
import pandas as pd
from scipy.stats import chi2_contingency
data=[[30,20],[35,15]]
chi2,p,dof,expected=chi2_contingency(data)
print(chi2)
print(p)
print(dof)
# Out:
# 0.7032967032967032
# 0.4016781664697727
# 1

# %%
import pandas as pd
from scipy.stats import chi2_contingency
data=pd.DataFrame({'male':[20,15,10],'female':[25,20,30]})
chi2,p,dof,expected=chi2_contingency(data)
print(chi2)
print(p)
print(dof)
# Out:
# 4.021164021164021
# 0.13391071453129127
# 2

# %%
# linear regression
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.DataFrame({'study_hours':[2,4,6,9,10],'marks':[20,40,60,80,100]})
x=df[['study_hours']]
y=df['marks']
model=LinearRegression()
model.fit(x,y)
predicted_marks=model.predict([[12]])
print(predicted_marks[0])
# Out:
# 114.37499999999997
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# multiple linear regression
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.DataFrame({'study_hours':[2,4,6,9,10],'marks':[20,40,60,80,100],'attendance':[70,75,80,90,95]})
x=df[['study_hours','attendance']]
y=df['marks']
model=LinearRegression()
model.fit(x,y)
predicted_marks=model.predict([[12,98]])
print(predicted_marks[0])
# Out:
# 112.0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# train test split
import pandas as pd
from sklearn.model_selection import train_test_split
x=[1,2,3,4,5,6,7,8]
y=[10,20,30,40,50,60,70,80]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# [1, 8, 3, 5, 4, 7]
# [2, 6]
# [10, 80, 30, 50, 40, 70]
# [20, 60]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
df=pd.read_csv("tips.csv")
print(df.head())
x=df[['total_bill','size']]
y=df['tip']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=104,shuffle=True)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251
#      total_bill  size
# 62        11.02     2
# 185       20.69     5
# 1         10.34     3
# 109       14.31     2
# 134       18.26     2
# ..          ...   ...
# 166       20.76     2
# 142       41.19     5
# ...
