# %%
import matplotlib.pyplot as plt
y1=[]
y2=[]

x=range(-100,100,10)
for i in x:
  y1.append(i**2)
for i in x:
  y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)
#plt.show()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('simple graph')
plt.axhline()
plt.axvline()
plt.show()

# %%
import matplotlib.pyplot as plt
y1=[]
y2=[]

x=range(-100,100,10)
for i in x:
  y1.append(i**2)
for i in x:
  y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)
#plt.show()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('simple graph')
plt.axhline(color='red')
plt.axvline(color='green')

plt.show()

# %%
import matplotlib.pyplot as plt
y1=[]
y2=[]

x=range(-100,100,10)
for i in x:
  y1.append(i**2)
for i in x:
  y2.append(-i**2)
plt.plot(x,y1)
plt.plot(x,y2)
#plt.show()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('simple graph')
plt.axhline(color='red')
plt.axvline(color='green')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')
plt.plot(df['deep learning'],df['machine learning'],color='red')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('line plot')
plt.xlim(10,50)
plt.ylim(10,50)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')

plt.plot(df['Mes'], df['data science'], label='data science')
plt.plot(df['Mes'], df['machine learning'], label='machine learning')
plt.plot(df['Mes'], df['deep learning'], label='deep learning')
plt.xlabel('Data')
plt.ylabel('popularity')
plt.title('Popularity of AI terms by date')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x=[0,1,2,3,4,5]
y=[0,1,4,9,16,25]

plt.scatter(x,y,color='blue')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('scatter plot')

plt.show()
# Out:
# /tmp/ipykernel_7559/3137195208.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt

x=[0,1,2,3,4,5]
y=[0,1,4,9,16,25]

plt.scatter(x,y,label='stars',color='blue',marker='o',s=30)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('scatter plot')
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')
plt.scatter(df['deep learning'],df['data science'],c='red',marker='^')
plt.title('scatter plot')
plt.xlabel('deep learning')
plt.ylabel('data science')
plt.show()

# %%
import matplotlib.pyplot as plt
values=[5,6,3,7,2]
names=["A","B","C","D","E"]
plt.bar(names,values,color="green")
plt.title("bar graph")
plt.xlabel("names")
plt.ylabel("values")
plt.show()

# %%
import matplotlib.pyplot as plt
values=[5,6,3,7,2]
names=["A","B","C","D","E"]
plt.barh(names,values,color="blue")
plt.title("bar graph")
plt.xlabel("names")
plt.ylabel("values")
plt.show()

# %%
import matplotlib.pyplot as plt
values=[5,6,3,7,2]
names=["A","B","C","D","E"]

c1=['red','green']
c2=['b','g']
plt.bar(names,values,width=0.5,color=c2)
plt.title("bar graph")
plt.xlabel("names")
plt.ylabel("values")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('temporal.csv')

plt.bar(df['Mes'], df['data science'], label='data science')
plt.bar(df['Mes'], df['machine learning'], label='machine learning')
plt.bar(df['Mes'], df['deep learning'], label='deep learning')
plt.xlabel('Data')
plt.ylabel('popularity')
plt.title('Popularity of AI terms by date')
plt.grid(True)
plt.legend()
plt.show()

# %%
import seaborn as sns
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv('temporal.csv')
sns.lineplot(x="deep learning",y="machine learning",data=df)
# Out:
# <Axes: xlabel='deep learning', ylabel='machine learning'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=pd.read_csv("/content/tips.csv")
sns.countplot(x='sex',data=df,palette='Set1')
plt.show()
# Out:
# /tmp/ipykernel_1555/1117600457.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=df,palette='Set1')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=pd.read_csv("/content/Iris.csv")
sns.countplot(x='Species',data=df,palette='Set1')
plt.show()
# Out:
# /tmp/ipykernel_1555/618219678.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Species',data=df,palette='Set1')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=pd.read_csv("/content/Iris.csv")
sns.countplot(x='Species',data=df,color='green',palette='Set1')
plt.show()
# Out:
# /tmp/ipykernel_1555/4029090036.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Species',data=df,color='green',palette='Set1')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)

sns.set_style("dark")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)

sns.set_style("whitegrid")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)

sns.set_style("white")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)

sns.set_style("ticks")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)

sns.set_style("ticks")
sns.despine()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.despine(left=False,bottom=True)
sns.set_style("ticks")
# sns.despine()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.despine(left=False)
sns.set_style("ticks")
# sns.despine()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


data=sns.load_dataset("tips")
sns.pairplot(data,hue="day")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


data=sns.load_dataset("iris")
sns.pairplot(data,hue="species")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=pd.read_csv('tips.csv')
sns.pairplot(df,hue='sex')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=pd.read_csv('tips.csv')
c_p={'Male':'Red','Female':'Green'}
sns.pairplot(df,hue='sex',palette=c_p)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


df=sns.load_dataset("tips")
sns.pairplot(df[['total_bill','tip','size']])
plt.show()

# %%
import numpy as np
import seaborn as sns

x=np.random.randn(200)
y=np.random.randn(200)

sns.kdeplot(x)
sns.kdeplot(y)
# Out:
# <Axes: ylabel='Density'>

# %%
import numpy as np
import seaborn as sns

x=np.random.randn(200)
y=np.random.randn(200)

sns.kdeplot(x)
sns.kdeplot(y)
sns.kdeplot(x, shade=True)
sns.kdeplot(y, shade=True)
# Out:
# /tmp/ipykernel_1555/1221913920.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x, shade=True)
# /tmp/ipykernel_1555/1221913920.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(y, shade=True)
# <Axes: ylabel='Density'>

# %%
import numpy as np
import seaborn as sns

x=np.random.randn(200)
y=np.random.randn(200)

sns.kdeplot(x,vertical=True)
# Out:
# /tmp/ipykernel_1555/2962525659.py:7: UserWarning:
#
# The `vertical` parameter is deprecated; assigning data to `y`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,vertical=True)
# <Axes: xlabel='Density'>

# %%
import numpy as np
import seaborn as sns

x=np.random.randn(200)
y=np.random.randn(200)

sns.kdeplot(x=x,y=y,shade=True)
# Out:
# /tmp/ipykernel_1555/3195860428.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=x,y=y,shade=True)
# <Axes: >

# %%
import numpy as np
import seaborn as sns

df=sns.load_dataset('iris')

sns.kdeplot(x=df['sepal_length'])
plt.show()

# %%
import numpy as np
import seaborn as sns

df=sns.load_dataset('iris')

sns.kdeplot(x=df['sepal_length'],y=df['sepal_width'],shade=True)
plt.show()
# Out:
# /tmp/ipykernel_1555/855520914.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df['sepal_length'],y=df['sepal_width'],shade=True)

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv('tips.csv')
sns.set_style('whitegrid')
sns.distplot(df['total_bill'],kde=False,color='red',bins=30)
plt.show()
# Out:
# /tmp/ipykernel_1555/3226654557.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'],kde=False,color='red',bins=30)

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv('tips.csv')
sns.set_style('whitegrid')
sns.distplot(df['total_bill'],kde=False,color='red',bins=20)
plt.show()
# Out:
# /tmp/ipykernel_1555/1751314059.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'],kde=False,color='red',bins=20)

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv('tips.csv')
sns.set_style('whitegrid')
sns.distplot(df['total_bill'],kde=False,color='red',bins=10)
plt.show()
# Out:
# /tmp/ipykernel_1555/23617351.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'],kde=False,color='red',bins=10)

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv('tips.csv')

sns.jointplot(x="total_bill",y="tip",data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=pd.read_csv("/content/tips.csv")

sns.countplot(x='sex',hue='smoker',data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=pd.read_csv("/content/tips.csv")

sns.countplot(y='sex',hue='smoker',data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# df=pd.read_csv("/content/tips.csv")
df=pd.read_csv("tips.csv")
plt.boxplot(df['total_bill'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc6a69dda30>,
#   <matplotlib.lines.Line2D at 0x7fc6a69ddcd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc6a69ddf70>,
#   <matplotlib.lines.Line2D at 0x7fc6a69de120>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc6a69dd700>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc6a69de3c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc6a69de690>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=pd.read_csv("/content/tips.csv")

plt.boxplot(df['tip'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc6a7ccc3b0>,
#   <matplotlib.lines.Line2D at 0x7fc6a7ccc6e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc6a7ccc9e0>,
#   <matplotlib.lines.Line2D at 0x7fc6a7cccce0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc6a7ccc140>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc6a7cccf80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc6a7ccd250>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# df=pd.read_csv("/content/Iris.csv")
df=pd.read_csv("Iris.csv")
plt.boxplot(df['SepalLengthCm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc6a6a557c0>,
#   <matplotlib.lines.Line2D at 0x7fc6a6a55ac0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc6a6a55d30>,
#   <matplotlib.lines.Line2D at 0x7fc6a6a55fa0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc6a6a554c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc6a6a56270>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc6a6a564e0>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# df=pd.read_csv("/content/Iris.csv")
df=pd.read_csv("Iris.csv")
plt.boxplot(df['SemalLengthCm'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_991/3408693882.py in <cell line: 0>()
#       4
#       5 # df=pd.read_csv("/content/Iris.csv")
# ----> 6 df=pd.read_csv("Iris.csv")
#       7 plt.boxplot(df['SemalLengthCm'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Iris.csv'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


data=np.random.randint(1,100,(10,10))
sns.heatmap(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


data=np.random.randint(1,100,(10,10))
sns.heatmap(data,vmin=30,vmax=70)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


data=np.random.randint(1,100,(10,10))
sns.heatmap(data,cmap='tab20')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


data=np.random.randint(1,100,(10,10))
sns.heatmap(data,cmap='coolwarm',center=50)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

df=pd.read_csv("tips.csv")
sns.heatmap(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_991/3774160297.py in <cell line: 0>()
#       5
#       6 df=pd.read_csv("tips.csv")
# ----> 7 sns.heatmap(df=data,cmap='tab20')
#       8 plt.show()
#
# TypeError: heatmap() missing 1 required positional argument: 'data'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data=[12,15,20,20,22,23,25,25,25,30,32,35,40]

plt.hist(data,bins=5,color='skyblue',edgecolor='black')
plt.title('histogram')
plt.xlabel('Value range')
plt.ylabel('frequency')
sns.despine()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=pd.read_csv("tips.csv")
sns.histplot(df['total_bill'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df=sns.load_dataset("iris")
sns.violinplot(x='species',y='sepal_length',data=df)
plt.title('violin plot')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


df=sns.load_dataset("iris")
sns.violinplot(x='petal_length',y='petal_width',data=df)
plt.title('violin plot')

plt.show()

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
print("First 5 rows of the dataframe:")
print(df.head())

skewness_values=df.skew()
print("\nSkewness values:")
print(skewness_values)
kurtosis_values=df.kurt()
print("\nKurtosis values:")
print(kurtosis_values)
# Out:
# First 5 rows of the dataframe:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Skewness values:
# sepal length (cm)    0.314911
# sepal width (cm)     0.318966
# petal length (cm)   -0.274884
# petal width (cm)    -0.102967
# dtype: float64
#
# Kurtosis values:
# sepal length (cm)   -0.552064
# sepal width (cm)     0.228249
# petal length (cm)   -1.402103
# petal width (cm)    -1.340604
# dtype: float64

# %%
import pandas as pd


tips=pd.read_csv("tips.csv")
df=pd.DataFrame(tips)
print("First 5 rows of the dataframe:")
print(tips.head())

skewness_values=df.skew()
print("\nSkewness values:")
print(skewness_values)
kurtosis_values=df.kurt()
print("\nKurtosis values:")
print(kurtosis_values)
# Out:
# First 5 rows of the dataframe:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      84             try:
# ---> 85                 return f(*args, **kwargs)
#      86             except ValueError as e:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in newfunc(values, axis, **kwargs)
#     476
# --> 477         return func(values, axis=axis, **kwargs)
#     478
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in nanskew(values, axis, skipna, mask)
#    1239     if values.dtype.kind != "f":
# -> 1240         values = values.astype("f8")
#    1241         count = _get_counts(values.shape, mask, axis)
#
# ValueError: could not convert string to float: 'Female'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7926/850821454.py in <cell line: 0>()
#       7 print(tips.head())
#       8
# ----> 9 skewness_values=df.skew()
#      10 print("\nSkewness values:")
#      11 print(skewness_values)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in skew(self, axis, skipna, numeric_only, **kwargs)
#   11759         **kwargs,
#   11760     ):
# > 11761         result = super().skew(axis, skipna, numeric_only, **kwargs)
#   11762         if isinstance(result, Series):
#   11763             result = result.__finalize__(self, method="skew")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in skew(self, axis, skipna, numeric_only, **kwargs)
#   12440         **kwargs,
#   12441     ) -> Series | float:
# > 12442         return self._stat_function(
#   12443             "skew", nanops.nanskew, axis, skipna, numeric_only, **kwargs
#   12444         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11560         # After possibly _get_data and transposing, we are now in the
#   11561         #  simple case where we can use BlockManager.reduce
# > 11562         res = df._mgr.reduce(blk_func)
#   11563         out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11564         if out_dtype is not None and out.dtype != "boolean":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in reduce(self, func)
#    1498         res_blocks: list[Block] = []
#    1499         for blk in self.blocks:
# -> 1500             nbs = blk.reduce(func)
#    1501             res_blocks.extend(nbs)
#    1502
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in reduce(self, func)
#     402         assert self.ndim == 2
#     403
# --> 404         result = func(self.values)
#     405
#     406         if self.values.ndim == 1:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in blk_func(values, axis)
#   11479                     return np.array([result])
#   11480             else:
# > 11481                 return op(values, axis=axis, skipna=skipna, **kwds)
#   11482
#   11483         def _get_data() -> DataFrame:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      90                 # object arrays that contain strings
#      91                 if is_object_dtype(args[0]):
# ---> 92                     raise TypeError(e) from e
#      93                 raise
#      94
#
# TypeError: could not convert string to float: 'Female'
