# %%
import pandas as pd

data={'apples':[3,2,0,1],'orange':[0,3,7,2]}
df=pd.DataFrame(data)
df

s=0

for i in range(4):
  s+=df.loc[i,'apples']

print(s)
# Out:
# 6

# %%
import pandas as pd

data={'id':[1,2,3,4,5],'name':["sairaj","hemanth","amar","aditya","gokul"],'branch':["cse","cse","cse","cse","cse"],'section':[1,1,2,2,4]}
df=pd.DataFrame(data,index=[450,526,483,669,716])
df
df['namelowe']=df['name'].str.lower()
df['nameupper']=df['branch'].str.upper()
print(df)
# df. to_csv('student.csv')

# df.to_json('student.json')
# Out:
#      id     name branch  section namelowe nameupper
# 450   1   sairaj    cse        1   sairaj       CSE
# 526   2  hemanth    cse        1  hemanth       CSE
# 483   3     amar    cse        2     amar       CSE
# 669   4   aditya    cse        2   aditya       CSE
# 716   5    gokul    cse        4    gokul       CSE

# %%
import pandas as pd
df=pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
movies_df=pd.read_csv("movies.csv",index_col="title")
# movies_df
# movies_df.head()
# movies_df.head(5)
# movies_df.tail(2)
# movies_df.info()
# movies_df.shape
# movies_df.describe()
#4803,23

# x=pd.concat([movies_df,movies_df])
# x.shape

# total_nans=movies_df.isna().sum().sum()
# nans_per_column=movies_df.isna().sum()

# print("Total NaNs: ",total_nans)
# print("NaNs per column: ",nans_per_column)
# movies_df.dropna()
# movies_df.dropna(axis=1)
# movies_df.fillna(0)
movies_df['original']=movies_df['original_title'].str.upper()
print(movies_df)
# Out:
#                                           index     budget  \
# title
# Avatar                                        0  237000000
# Pirates of the Caribbean: At World's End      1  300000000
# Spectre                                       2  245000000
# The Dark Knight Rises                         3  250000000
# John Carter                                   4  260000000
# ...                                         ...        ...
# El Mariachi                                4798     220000
# Newlyweds                                  4799       9000
# Signed, Sealed, Delivered                  4800          0
# Shanghai Calling                           4801          0
# My Date with Drew                          4802          0
#
#                                                                             genres  \
# title
# Avatar                                    Action Adventure Fantasy Science Fiction
# ...

# %%
y=x.drop_duplicates()
y.shape
# Out:
# (4803, 23)

# %%
t=movies_df.drop_duplicates(inplace=True)

# %%
import pandas as pd
ex=[{'a':1,'b':2},{'a':5,'b':10,'c':20}]
df1=pd.DataFrame(ex,index=['first','second'],columns=['a','b'])
df2=pd.DataFrame(ex,index=['first','second'],columns=['a','b1'])

# print(df1)
# print(df2)
# df1. to_csv('df1.csv')
# df2. to_csv('df2.csv')
# Out:
#         a   b
# first   1   2
# second  5  10
#         a  b1
# first   1 NaN
# second  5 NaN

# %%
import pandas as pd
df={'one':pd.Series([1,2,3],index=['a','b','c']),
   'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
# df=pd.DataFrame(d)
# df

# df['three']=pd.Series([10,20,30],index=['a','b','c'])
# df
# df['four']=df['one']+df['three']
# df
# del df['one']
# df
# df=pd.DataFrame(d)
# df[2:4]
# Out:
#    one  two
# c  3.0    3
# d  NaN    4

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({ 'Age':[25,30,np.nan,40,35],
                  'Deparymnrt':['HR','Finance','Finance',np.nan,'IT']})
print(df)
df['Age'].fillna(df['Age'].mean(),inplace=True)

df['Deparymnrt'].fillna(df['Deparymnrt'].mode()[0],inplace=True)
print(df)
# Out:
#     Age Deparymnrt
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  35.0         IT
#     Age Deparymnrt
# 0  25.0         HR
# 1  30.0    Finance
# 2  32.5    Finance
# 3  40.0    Finance
# 4  35.0         IT
# /tmp/ipykernel_10011/3994942935.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)
# ...

# %%
df_ffill=df.copy()
df_ffill.fillna(method='ffill',inplace=True)
print(df_ffill)
# Out:
#     Age Deparymnrt
# 0  25.0         HR
# 1  30.0    Finance
# 2  32.5    Finance
# 3  40.0    Finance
# 4  35.0         IT
# /tmp/ipykernel_10011/527151055.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill.fillna(method='ffill',inplace=True)

# %%
df_bfill=df.copy()
df_bfill.fillna(method='bfill',inplace=True)
print(df_bfill)
# Out:
#     Age Deparymnrt
# 0  25.0         HR
# 1  30.0    Finance
# 2  32.5    Finance
# 3  40.0    Finance
# 4  35.0         IT
# /tmp/ipykernel_10011/2985061711.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill.fillna(method='bfill',inplace=True)

# %%
import pandas as pd

# Sample dataset with inconsistent date formats
df = pd.DataFrame({
    'Date': ['2025-01-05', '05/01/2025', 'Jan 5, 2025', '2025.01.05']
})

# Convert all dates to standard ISO format (YYYY-MM-DD)
df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

print(df)
# Out:
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'BOB', 'charlie', 'DAVID']
})

# Convert all names to lowercase
df['Name_lower'] = df['Name'].str.lower()
print(df)

# Convert all names to uppercase
df['Name_upper'] = df['Name'].str.upper()

print(df)
# Out:
#       Name Name_lower
# 0    Alice      alice
# 1      BOB        bob
# 2  charlie    charlie
# 3    DAVID      david
#       Name Name_lower Name_upper
# 0    Alice      alice      ALICE
# 1      BOB        bob        BOB
# 2  charlie    charlie    CHARLIE
# 3    DAVID      david      DAVID
